# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marvel = pd.read_csv('marvel_powers.csv')

# %%
marvel.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x  Gender EyeColor  \
# 0           0   0         A-Bomb        good    Male   yellow
# 1           1   3    Abomination         bad    Male    green
# 2           2   4        Abraxas         bad    Male     blue
# 3           3   5  Absorbing Man         bad    Male     blue
# 4           4   8       Agent 13        good  Female     blue
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 0              Human   No Hair  Marvel Comics         -  ...         False
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 4                  -     Blond  Marvel Comics         -  ...           NaN
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %% [markdown]
# #### Get frequency of types of super heroes

# %%
marvel['Alignment_x'].value_counts()
# Out:
# Alignment_x
# good       254
# bad        114
# neutral     11
# -            3
# Name: count, dtype: int64

# %%
for col in marvel.columns:
    print(col)
# Out:
# Unnamed: 0
# ID
# Name
# Alignment_x
# Gender
# EyeColor
# Race
# HairColor
# Publisher
# SkinColor
# Height
# Weight
# Intelligence_x
# Strength
# Speed
# Durability_x
# Power
# Combat
# Total
# Agility
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Durability_y
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Intelligence_y
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# ...

# %%
good_marvel = marvel[marvel['Alignment_x'] == 'good']

# %%
good_marvel.head()
# Out:
#     Unnamed: 0  ID        Name Alignment_x  Gender EyeColor   Race HairColor  \
# 0            0   0      A-Bomb        good    Male   yellow  Human   No Hair
# 4            4   8    Agent 13        good  Female     blue      -     Blond
# 5            5   9   Agent Bob        good    Male    brown  Human     Brown
# 6            6  10  Agent Zero        good    Male        -      -         -
# 10          10  22       Angel        good    Male     blue      -     Blond
#
#         Publisher SkinColor  ...  Web Creation  Reality Warping  Odin Force  \
# 0   Marvel Comics         -  ...         False            False       False
# 4   Marvel Comics         -  ...           NaN              NaN         NaN
# 5   Marvel Comics         -  ...         False            False       False
# 6   Marvel Comics         -  ...         False            False       False
# 10  Marvel Comics         -  ...         False            False       False
#
# ...

# %% [markdown]
# ### Create a count plot of all character types, categorize based on gender

# %%
sns.countplot(data=marvel, x='Alignment_x', hue='Gender')
# Out:
# <Axes: xlabel='Alignment_x', ylabel='count'>

# %%
# Fastest 5 good characters
good_marvel[['Name','Gender','Race','Speed']].sort_values(by='Speed', ascending=False).head()
# Out:
#                Name  Gender            Race  Speed
# 183  Jack of Hearts    Male           Human  100.0
# 43       Black Bolt    Male         Inhuman  100.0
# 321        Stardust    Male               -  100.0
# 252         Nova II  Female  Human / Cosmic  100.0
# 270     Quicksilver    Male          Mutant  100.0

# %%
# Powerful top5 characters
good_marvel[['Name','Gender','Race','Speed','Power']].sort_values(by='Power', ascending=False).head()
# Out:
#            Name  Gender            Race  Speed  Power
# 252     Nova II  Female  Human / Cosmic  100.0  100.0
# 177      Iceman    Male          Mutant   53.0  100.0
# 43   Black Bolt    Male         Inhuman  100.0  100.0
# 260     Phoenix  Female          Mutant   67.0  100.0
# 35     Beyonder    Male   God / Eternal   23.0  100.0

# %%
# Most powerful good character in terms of total points
good_marvel[['Name', 'Gender','Total']].sort_values(by='Total',ascending=False).head()
# Out:
#           Name  Gender  Total
# 321   Stardust    Male  568.0
# 330       Thor    Male  546.0
# 251       Nova    Male  538.0
# 184  Jean Grey  Female  517.0
# 260    Phoenix  Female  517.0

# %% [markdown]
# ### Get all bad characters

# %%
bad_marvel = marvel[marvel['Alignment_x'] == 'bad']

# %%
bad_marvel.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x Gender EyeColor  \
# 1           1   3    Abomination         bad   Male    green
# 2           2   4        Abraxas         bad   Male     blue
# 3           3   5  Absorbing Man         bad   Male     blue
# 7           7  11     Air-Walker         bad   Male     blue
# 8           8  12           Ajax         bad   Male    brown
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 7                  -     White  Marvel Comics         -  ...         False
# 8             Cyborg     Black  Marvel Comics         -  ...         False
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
# 5 most powerful bad characters
bad_marvel[['Name','Power','Gender','Speed']].sort_values(by='Power', ascending=False).head()
# Out:
#          Name  Power Gender  Speed
# 118  Dormammu  100.0   Male   83.0
# 328    Thanos  100.0   Male   17.0
# 344    Ultron  100.0   Male   42.0
# 224  Mephisto  100.0   Male   35.0
# 126    Exodus  100.0   Male   28.0

# %%
# 5 most fastest characters
bad_marvel[['Name','Power','Gender','Speed']].sort_values(by='Speed', ascending=False).head()
# Out:
#               Name  Power Gender  Speed
# 7       Air-Walker  100.0   Male  100.0
# 129  Fallen One II  100.0   Male   83.0
# 120            Ego   71.0      -   83.0
# 118       Dormammu  100.0   Male   83.0
# 2          Abraxas  100.0   Male   83.0

# %% [markdown]
# #### count plot of bad marvels based on gender

# %%
sns.countplot(data=bad_marvel, x='Gender', hue='Race')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Most powerful in terms of total character in bad 
bad_marvel[['Name', 'Gender', 'Total']].sort_values(by='Total', ascending=False).head()
# Out:
#               Name Gender  Total
# 118       Dormammu   Male  546.0
# 215          Magus   Male  531.0
# 2          Abraxas   Male  526.0
# 129  Fallen One II   Male  512.0
# 256      Onslaught   Male  505.0

# %% [markdown]
# ### Find correation between speed and weight

# %%
sns.scatterplot(data=marvel, x='Speed',y='Weight')
# Out:
# <Axes: xlabel='Speed', ylabel='Weight'>

# %%
# not much relation between speed and weight

# %% [markdown]
# #### Create relationship chart between longevity and power

# %%
sns.scatterplot(data=marvel, ='Longevity', y='Power')
# Out:
# <Axes: xlabel='Longevity', ylabel='Power'>
